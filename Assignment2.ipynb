# %% [markdown]
# <a href="https://colab.research.google.com/github/amritashaji06-cmd/ict_assignments/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,101):
  if i%3==0:
     print('Fizz')
  elif i%5==0:
     print('Buzz')
  elif i%3==0 & i%5==0:
     print('Fizzbuzz')
  else:
     print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
a= int(input('number of unit consumed:'))
if a<=100:
  bill = a*5
  print('total bill amound:',bill)
elif a<=200:
  bill = (100*5)+((a-100)*7)
  print('total bill amound:',bili)
else:
  bill = (100*5)+(100*7)+((a-200)*10)
  print('total bill amound: ',bill)
# Out:
# number of unit consumed:245
# total bill amound:  1650

# %%
a ='*'
for i in range(1,6):
  print(a*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
a = input('enter a num or string:')

if a==a[::-1]:
  print('the givennum or string is palindrome')
else:
  print('the given num or string is not palinrome')
# Out:
# enter a num or string:121
# the givennum or string is palindrome
